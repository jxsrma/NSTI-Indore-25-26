# %%
# Ram_Name = "Ram Yadav"
# Ram_Class = 10
# Ram_Section = 'A'
# Ram_School = "ABC International School"
# Ram_Roll_No = 38
# Ram_Contact = "+91-987-789-9988"

# %%
# Shyam_Name = "Shyam Yadav"
# Shyam_Class = 10
# Shyam_Section = 'A'
# Shyam_School = "ABC International School"
# Shyam_Roll_No = 43
# Shyam_Contact = "+91-987-789-9989"

# %%
# Shyam1_Roll_No = 44

# %%
Ram = {
    'Name':  'Ram Yadav',
    'Class': 10,
    'Section': 'A',
    'School': 'ABC International School',
    'Roll_No': 38,
    'Contact': '+91-987-789-9988',
    'Subject': ['P','C','M']
}

# %%
type(Ram)
# Out:
# dict

# %%
Ram
# Out:
# {'Name': 'Ram Yadav',
#  'Class': 10,
#  'Section': 'A',
#  'School': 'ABC International School',
#  'Roll_No': 38,
#  'Contact': '+91-987-789-9988',
#  'Subject': ['P', 'C', 'M']}

# %%
Shyam = {
    'Name':  'Shyam Yadav',
    'Class': 10,
    'Section': 'A',
    'School': 'ABC International School',
    'Roll_No': 32,
    'Contact': '+91-987-789-9989',
    'Subject': ['Accounts','BS','Stats','Eco']
}

# %%
Shyam
# Out:
# {'Name': 'Shyam Yadav',
#  'Class': 10,
#  'Section': 'A',
#  'School': 'ABC International School',
#  'Roll_No': 32,
#  'Contact': '+91-987-789-9989',
#  'Subject': ['Accounts', 'BS', 'Stats', 'Eco']}

# %%
A10 = {
    "Ram": Ram,
    "Shyam": Shyam,
    "Shyam_0101": {
        'Name':  'Shyam Verma',
        'Class': 10,
        'Section': 'A',
        'School': 'ABC International School',
        'Roll_No': 32,
        'Contact': '+91-987-789-9989',
        'Subject': ['Accounts', 'BS', 'Stats', 'Eco']
    }
}

A10
# Out:
# {'Ram': {'Name': 'Ram Yadav',
#   'Class': 10,
#   'Section': 'A',
#   'School': 'ABC International School',
#   'Roll_No': 38,
#   'Contact': '+91-987-789-9988',
#   'Subject': ['P', 'C', 'M']},
#  'Shyam': {'Name': 'Shyam Yadav',
#   'Class': 10,
#   'Section': 'A',
#   'School': 'ABC International School',
#   'Roll_No': 32,
#   'Contact': '+91-987-789-9989',
#   'Subject': ['Accounts', 'BS', 'Stats', 'Eco']},
#  'Shyam_0101': {'Name': 'Shyam Verma',
#   'Class': 10,
#   'Section': 'A',
#   'School': 'ABC International School',
#   'Roll_No': 32,
#   'Contact': '+91-987-789-9989',
#   'Subject': ['Accounts', 'BS', 'Stats', 'Eco']}}

# %%
# # For Later Use
# import json

# with open("A10.json", "w") as json_file:
#     json.dump(A10, json_file, indent=4)

# %%
Ram['Roll_No']
# Out:
# 38

# %%
Ram['Contact']
# Out:
# '+91-987-789-9988'

# %%
Shyam['Contact']
# Out:
# '+91-987-789-9989'

# %%
A10['Shyam']['Contact']
# Out:
# '+91-987-789-9989'

# %%
A10['Ram']['Subject'][1]
# Out:
# 'C'

# %%
A10['Gauri'] = {
    'Name': 'Gauri Gurjar',
    'Class': 10,
    'Section': 'A',
    'School': 'ABC International School',
    'Roll_No': 20,
    'Contact': '+91-123-456-7890',
    'Subject': ['P', 'C', 'M']}

# %%
A10
# Out:
# {'Ram': {'Name': 'Ram Yadav',
#   'Class': 10,
#   'Section': 'A',
#   'School': 'ABC International School',
#   'Roll_No': 38,
#   'Contact': '+91-987-789-9988',
#   'Subject': ['P', 'C', 'M']},
#  'Shyam': {'Name': 'Shyam Yadav',
#   'Class': 10,
#   'Section': 'A',
#   'School': 'ABC International School',
#   'Roll_No': 32,
#   'Contact': '+91-987-789-9989',
#   'Subject': ['Accounts', 'BS', 'Stats', 'Eco']},
#  'Shyam_0101': {'Name': 'Shyam Verma',
#   'Class': 10,
#   'Section': 'A',
#   'School': 'ABC International School',
#   'Roll_No': 32,
#   'Contact': '+91-987-789-9989',
#   'Subject': ['Accounts', 'BS', 'Stats', 'Eco']},
#  'Gauri': {'Name': 'Gauri Gurjar',
#   'Class': 10,
#   'Section': 'A',
#   'School': 'ABC International School',
#   'Roll_No': 20,
#   'Contact': '+91-123-456-7890',
#   'Subject': ['P', 'C', 'M']}}

# %%
A10['Shyam_0101'] = "Drop Out"

# %%
A10
# Out:
# {'Ram': {'Name': 'Ram Yadav',
#   'Class': 10,
#   'Section': 'A',
#   'School': 'ABC International School',
#   'Roll_No': 38,
#   'Contact': '+91-987-789-9988',
#   'Subject': ['P', 'C', 'M']},
#  'Shyam': {'Name': 'Shyam Yadav',
#   'Class': 10,
#   'Section': 'A',
#   'School': 'ABC International School',
#   'Roll_No': 32,
#   'Contact': '+91-987-789-9989',
#   'Subject': ['Accounts', 'BS', 'Stats', 'Eco']},
#  'Shyam_0101': 'Drop Out',
#  'Gauri': {'Name': 'Gauri Gurjar',
#   'Class': 10,
#   'Section': 'A',
#   'School': 'ABC International School',
#   'Roll_No': 20,
#   'Contact': '+91-123-456-7890',
#   'Subject': ['P', 'C', 'M']}}

# %%
A10.keys()
# Out:
# dict_keys(['Ram', 'Shyam', 'Shyam_0101', 'Gauri'])

# %%
A10.values()
# Out:
# dict_values([{'Name': 'Ram Yadav', 'Class': 10, 'Section': 'A', 'School': 'ABC International School', 'Roll_No': 38, 'Contact': '+91-987-789-9988', 'Subject': ['P', 'C', 'M']}, {'Name': 'Shyam Yadav', 'Class': 10, 'Section': 'A', 'School': 'ABC International School', 'Roll_No': 32, 'Contact': '+91-987-789-9989', 'Subject': ['Accounts', 'BS', 'Stats', 'Eco']}, 'Drop Out', {'Name': 'Gauri Gurjar', 'Class': 10, 'Section': 'A', 'School': 'ABC International School', 'Roll_No': 20, 'Contact': '+91-123-456-7890', 'Subject': ['P', 'C', 'M']}])

# %%
Ram.keys()
# Out:
# dict_keys(['Name', 'Class', 'Section', 'School', 'Roll_No', 'Contact', 'Subject'])

# %%
Ram.values()
# Out:
# dict_values(['Ram Yadav', 10, 'A', 'ABC International School', 38, '+91-987-789-9988', ['P', 'C', 'M']])
