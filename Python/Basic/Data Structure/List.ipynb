# %%
name = [1, 'A', 2, 'B', 3.5, 'C', 'Hello AIPA',
        [5, 6, 7,
         [8, 9, 10]
         ]
        ]

# %%
print(name)
print(type(name))
# Out:
# [1, 'A', 2, 'B', 3.5, 'C', 'Hello AIPA', [5, 6, 7, [8, 9, 10]]]
# <class 'list'>

# %%
print(name[2])
print(name[3])
print(name[4])
print(name[6])
# Out:
# 2
# B
# 3.5
# Hello AIPA

# %%
print(name[7])
print(name[7][2])
# Out:
# [5, 6, 7, [8, 9, 10]]
# 7

# %%
print(name[7])
print(name[7][3][1])
# Out:
# [5, 6, 7, [8, 9, 10]]
# 9

# %%
marks = [50,60,70,80,90,100]

# %%
len(marks)
# Out:
# 6

# %%
marks.append(75)

# %%
print(marks) # For Py Filee
marks # only for Notebook
# Out:
# [50, 60, 70, 80, 90, 100, 75]
# [50, 60, 70, 80, 90, 100, 75]

# %%
marks = sorted(marks)

# %%
marks
# Out:
# [50, 60, 70, 75, 80, 90, 100]

# %%
marks.insert(1,55)

# %%
marks
# Out:
# [50, 55, 60, 70, 75, 80, 90, 100]

# %%
marks[4] = 72

# %%
marks
# Out:
# [50, 55, 60, 70, 72, 80, 90, 100]

# %%
marks[2:6]
# Out:
# [60, 70, 72, 80]

# %%
marks[2:8:2]
# Out:
# [60, 72, 90]

# %%
repeated_number = [4, 6, 7, 4, 3, 5, 7, 9, 6, 3, 2, 3, 5, 7, 8, 4, 4, 4, 4, 4]

# %%
repeated_number.index(9)
# Out:
# 7

# %%
repeated_number.index(3)
# Out:
# 4

# %%
repeated_number.index(3,6)
# Out:
# 9

# %%
x = [1,2,3]
y = [1,2,3]

x is y
# Out:
# False

# %%
i = [1,2,3]
j = i

i is j
# Out:
# [1, 2, 3]

# %%
m = [1, 'A', 2, 'B', 3.5, 'C', 'Hello AIPA', [5, 6, 7, [8, 9, 10]]]
n = m.copy()
m is n
# Out:
# False
