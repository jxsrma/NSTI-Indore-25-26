# %%
nsti = ("hello", 5, (3, 5, (8, 0, 6)),5,7,5,4,3,2,4,5,7,8,7,[5,3,4,6,7],{4,4,6,6,})

# %%
print(nsti)
# Out:
# ('hello', 5, (3, 5, (8, 0, 6)), 5, 7, 5, 4, 3, 2, 4, 5, 7, 8, 7, [5, 3, 4, 6, 7], {4, 6})

# %%
print(len(nsti))
# Out:
# 16

# %%
nsti.count(5)
# Out:
# 4

# %%
nsti.index(4)
# Out:
# 6

# %%
nsti[6]
# Out:
# 4
