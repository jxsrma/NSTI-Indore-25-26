# %%
import requests

# %%
URL = "https://aimicrodegree.org/login"

# %%
response = requests.get(URL)

# %%
print(response.status_code)
# Out:
# 200

# %%
print(response.headers['Date'])
# Out:
# Wed, 19 Nov 2025 09:13:38 GMT

# %%
print((response._content))
# Out:
# b'<!doctype html>\n<html lang="en">\n\n<style type="text/css">\n\t.desktoplogo{width: 300px;}\t\n</style>\n\t<head>\n\t\t\n\n\t\t<!-- Meta data -->\n\t\t<meta charset="UTF-8">\n\t\t<meta name=\'viewport\' content=\'width=device-width, initial-scale=1.0, user-scalable=0\'>\n\t\t<meta http-equiv="X-UA-Compatible" content="IE=edge">\n\t\t<!-- Favicon -->\n\t\t<link rel="icon" href="https://aimicrodegree.org/aimicrodegree/images/brand/favicon.ico" type="image/x-icon"/>\n\t\t<link rel="shortcut icon" type="image/x-icon" href="https://aimicrodegree.org/aimicrodegree/images/brand/favicon.ico" />\n\n\t\t<!-- Title -->\n\t\t<title>Login</title>\n\n\t\t<!-- Bootstrap css -->\n\t\t<link href="https://aimicrodegree.org/plugins/bootstrap/css/bootstrap.css" rel="stylesheet" />\n\n\t\t<!-- Style css -->\n\t\t<link href="https://aimicrodegree.org/aimicrodegree/css/style.css" rel="stylesheet" />\n\n\t\t<!-- Font-awesome  css -->\n\t\t<link href="https://aimicrodegree.org/css/icons.css" rel="stylesheet"/>\n\n\t\t<!--Select2 css -->\n\t\t<link href="https://aimicrodegree.org/plugins/select2/select2.css" rel="stylesheet" />\n\n\t\t<!-- Cookie css -->\n\t\t<link href="https://aimicrodegree.org/plugins/cookie/cookie.css" rel="stylesheet">\n\n\t\t<!-- Owl Theme css-->\n\t\t<link href="https://aimicrodegree.org/plugins/owl-carousel/owl.carousel.css" rel="stylesheet" />\n\n\t\t<!-- Color Skin css -->\n\t\t<link id="theme" rel="stylesheet" type="text/css" media="all" href="https://aimicrodegree.org/color-skins/color.css" />\n\n\t\t<link rel="stylesheet" type="text/css" href="https://aimicrodegree.org/aimicrodegree/css/custom.css">\n\t\t<!-- Google tag (gtag.js) https://aimicrodegree.org-->\n<script async src="https://www.googletagmanager.com/gtag/js?id=G-XDQFVT8DQF"></script>\n<script>\n  window.dataLayer = window.dataLayer || [];\n  function gtag(){dataLayer.push(arguments);}\n  gtag(\'js\', new Date());\n\n  gtag(\'config\', \'G-XDQFVT8DQF\');\n</script>\n\t</head>\n\t<!--Topbar-->\n\t\t<div class="header-main">\n\t\t\t\t\t<div class="top-bar pt-1" style="background:#00A4EF">\n\t\t\t\t<div class="container">\n\t\t\t\t\t<div class="row">\n\t\t\t\t\t\t<div class="col-xl-8 col-lg-8 col-sm-4 col-12">\n\t\t\t\t\t\t\t<div class="top-bar-start d-flex">\n\t\t\t\t\t\t\t\t<div class="clearfix">\n\t\t\t\t\t\t\t\t<!--\t<ul class="socials">\n\t\t\t\t\t\t\t\t\t\t<li>\n\t\t\t\t\t\t\t\t\t\t\t<a class="social-icon text-dark" href="javascript:void(0)"><i class="fe fe-facebook"></i></a>\n\t\t\t\t\t\t\t\t\t\t</li>\n\t\t\t\t\t\t\t\t\t\t<li>\n\t\t\t\t\t\t\t\t\t\t\t<a class="social-icon text-dark" href="javascript:void(0)"><i class="fe fe-twitter"></i></a>\n\t\t\t\t\t\t\t\t\t\t</li>\n\t\t\t\t\t\t\t\t\t\t<li>\n\t\t\t\t\t\t\t\t\t\t\t<a class="social-icon text-dark" href="javascript:void(0)"><i class="fe fe-linkedin"></i></a>\n\t\t\t\t\t\t\t\t\t\t</li>\n\t\t\t\t\t\t\t\t\t\t<li>\n\t\t\t\t\t\t\t\t\t\t\t<a class="social-icon text-dark" href="javascript:void(0)"><i class="fe fe-instagram"></i></a>\n\t\t\t\t\t\t\t\t\t\t</li>\n\t\t\t\t\t\t\t\t\t</ul> -->\n\t\t\t\t\t\t\t\t</div>\n\t\t\t\t\t\t\t</div>\n\t\t\t\t\t\t</div>\n\t\t\t\t\t\t<div class="col-xl-4 col-lg-4 col-sm-8 col-12">\n\t\t\t\t\t\t\t<div class="top-bar-end">\n&nbsp;\n\t\t\t\t\t\t\t</div>\n\t\t\t\t\t\t</div>\n\t\t\t\t\t</div>\n\t\t\t\t</div>\n\t\t\t</div><!--/Topbar-->\n\n\t\t\t<!--Section-->\n\t\t\t<div class="cover-image bg-background-1" data-bs-image-src="https://aimicrodegree.org/aimicrodegree/images/banners/slider-bg.jpg">\n\n\t\t\t\t<!--Topbar-->\n\t\t\t\t<div class="header-main">\n\t\t\t\t\t<!-- Mobile Header -->\n\t\t\t\t\t<div class="sticky">\n\t\t\t\t\t\t<div class="horizontal-header clearfix ">\n\t\t\t\t\t\t\t<div class="container">\n\t\t\t\t\t\t\t\t<a id="horizontal-navtoggle" class="animated-arrow"><span></span></a>\n\t\t\t\t\t\t\t\t<span class="smllogo"><img src="https://aimicrodegree.org/aimicrodegree/images/brand/aimicrodegree-logo-new.png" width="250" alt="img"/></span>\n\t\t\t\t\t\t\t\t<span class="smllo ...
