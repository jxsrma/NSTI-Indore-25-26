# %%
import tensorflow as tf

# %%
o = tf.zeros([2,3],dtype=tf.int32)
o
# Out:
# <tf.Tensor: shape=(2, 3), dtype=int32, numpy=
# array([[0, 0, 0],
#        [0, 0, 0]])>

# %%
i = tf.ones([2,3],dtype=tf.int32)
i
# Out:
# <tf.Tensor: shape=(2, 3), dtype=int32, numpy=
# array([[1, 1, 1],
#        [1, 1, 1]])>

# %%
r = tf.random.normal([4, 4], mean=50, stddev=40)
r
# Out:
# <tf.Tensor: shape=(4, 4), dtype=float32, numpy=
# array([[  6.7203293,  72.2377   ,  20.441198 , -10.505909 ],
#        [105.67952  ,  93.93143  ,  36.10672  ,  58.523937 ],
#        [ 28.00847  ,  38.37896  ,  40.946877 ,  20.848793 ],
#        [-46.789154 ,  47.10486  ,  87.931625 , 101.25191  ]],
#       dtype=float32)>

# %%
tf.config.list_physical_devices('GPU')
# Out:
# []

# %%
tf.config.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %%
import torch

if torch.cuda.is_available():
    device = torch.device("cuda")
    print(f"GPU: {torch.cuda.get_device_name(0)} is available. Using device: {device}")
else:
    device = torch.device("cpu")
    print("No GPU available. Using device: CPU")

# Create a random tensor on the specified device
x = torch.randn(5, 3, device=device)
print("Tensor on device:", x.device)
# Out:
# GPU: NVIDIA GeForce RTX 3050 Laptop GPU is available. Using device: cuda
# Tensor on device: cuda:0
