# %%
import transformers
transformers.__version__
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import transformers
#       2 transformers.__version__
#
# File c:\Users\Jash\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\__init__.py:30
#      27 from typing import TYPE_CHECKING
#      29 # Check the dependencies satisfy the minimal versions required.
# ---> 30 from . import dependency_versions_check
#      31 from .utils import (
#      32     OptionalDependencyNotAvailable,
#      33     _LazyModule,
#    (...)     40     is_pretty_midi_available,
#      41 )
#      43 # Note: the following symbols are deliberately exported with `as`
#      44 # so that mypy, pylint or other static linters can recognize them,
#      45 # given that they are not exported using `__all__` in this file.
#
# ...

# %%
transformers.pipelines.get_supported_tasks()
# Out:
# ['any-to-any',
#  'audio-classification',
#  'automatic-speech-recognition',
#  'depth-estimation',
#  'document-question-answering',
#  'feature-extraction',
#  'fill-mask',
#  'image-classification',
#  'image-feature-extraction',
#  'image-segmentation',
#  'image-text-to-text',
#  'keypoint-matching',
#  'mask-generation',
#  'ner',
#  'object-detection',
#  'sentiment-analysis',
#  'table-question-answering',
#  'text-classification',
#  'text-generation',
#  'text-to-audio',
#  'text-to-speech',
#  'token-classification',
#  'video-classification',
#  'zero-shot-audio-classification',
#  'zero-shot-classification',
#  'zero-shot-image-classification',
#  'zero-shot-object-detection']

# %%
generate = transformers.pipeline(task='text-generation',model="gpt2")
# Out:
# ...
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]

# %%
response = generate(text_inputs="GTA 5 is")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)

# %%
print(response[0]['generated_text'])
# Out:
# 35mm f1.8 lens is good for small, wide-angle photography but is not as sensitive to light as a Sony SLR. So, you can get the most out of the camera by using a Canon or Nikon DSLR.
#
# If you're interested in shooting outdoors, take advantage of the Canon and Nikon SLRs. The Nikon is more compact and more powerful, and the SLR is more expensive.
#
# To shoot indoors, take a camera that has an aperture of f1.8. You can use this for portraits and landscape photography.
#
# If you have a Nikon SLR, you can also use this same camera for indoor shooting, but you have to install a tripod.
#
# If you are using a Sony, you may want to add some filters to the lens to help you find the best aperture for your subject.
#
# If you're shooting outdoor and want a nice view of the outdoors, you can shoot indoors with a lens that will be able to help you with that.
#
# If you are shooting in a street with a wide angle lens, you can use a Sony.
#
# ...

# %%
# !pip install diffusers transformers accelerate torch

# %%
from diffusers import StableDiffusionPipeline
import torch

# %%
# load the model  
pipe = StableDiffusionPipeline.from_pretrained(
    "runwayml/stable-diffusion-v1-5",
    torch_dtype=torch.float16
)
# Out:
# ...
# Loading weights:   0%|          | 0/196 [00:00<?, ?it/s]
# CLIPTextModel LOAD REPORT from: C:\Users\Jash\.cache\huggingface\hub\models--runwayml--stable-diffusion-v1-5\snapshots\451f4fe16113bff5a5d2269ed5ad43b0592e9a14\text_encoder
# Key                                | Status     |  |
# -----------------------------------+------------+--+-
# text_model.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Loading weights:   0%|          | 0/396 [00:00<?, ?it/s]
# StableDiffusionSafetyChecker LOAD REPORT from: C:\Users\Jash\.cache\huggingface\hub\models--runwayml--stable-diffusion-v1-5\snapshots\451f4fe16113bff5a5d2269ed5ad43b0592e9a14\safety_checker
# Key                                               | Status     |  |
# --------------------------------------------------+------------+--+-
# vision_model.vision_model.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# ...

# %%
pipe = pipe.to('cuda')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 pipe = pipe.to('cuda')
#
# File c:\Users\Jash\AppData\Local\Programs\Python\Python312\Lib\site-packages\diffusers\pipelines\pipeline_utils.py:565, in DiffusionPipeline.to(self, *args, **kwargs)
#     563     module.to(device=device)
#     564 elif not is_loaded_in_4bit_bnb and not is_loaded_in_8bit_bnb and not is_group_offloaded:
# --> 565     module.to(device, dtype)
#     567 if (
#     568     module.dtype == torch.float16
#     569     and str(device) in ["cpu"]
#     570     and not silence_dtype_warnings
#     571     and not is_offloaded
#     572 ):
#     573     logger.warning(
#     574         "Pipelines loaded with `dtype=torch.float16` cannot run with `cpu` device. It"
#     575         " is not recommended to move them to `cpu` as running them will fail. Please make"
# ...

# %%
# prompt:
prompt = "A futuristic AI classroom with robots teaching students"

# %%
pipe = pipe.to('cuda')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 pipe = pipe.to('cuda')
#
# NameError: name 'pipe' is not defined

# %%
# generate the image
image = pipe(prompt).images[0]
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
image.save("output1.png")
