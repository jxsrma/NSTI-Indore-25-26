# %%
print('********hello******')
# Out:
# ********hello******

# %%
for i in range(5):
    print('h')
# Out:
# h
# h
# h
# h
# h

# %%
print(5+15)
# Out:
# 20

# %%
a = 17

# %%
print(a)
# Out:
# 17

# %%
# Hello

# %% [markdown]
# ### Hello
# - A
# - B
# - C
