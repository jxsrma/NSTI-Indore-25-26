# %%
import pandas as pd
import numpy as np

np.random.seed(42)

rows = 40

df = pd.DataFrame({
    "Student_ID": range(1001, 1001 + rows),

    "Age": np.random.choice([14, 15, 16, 17, None], rows),

    "Gender": np.random.choice(
        ["Male", "Female", "male", "female", None],
        rows
    ),

    "Class": np.random.choice(
        ["9th", "10th", "11th", "12th", None],
        rows
    ),

    "Attendance_Percent": np.random.choice(
        [65, 70, 75, 80, 85, 90, 95, None],
        rows
    ),

    "Math_Score": np.random.choice(
        [35, 45, 55, 65, 75, 85, None],
        rows
    ),

    "Science_Score": np.random.choice(
        [40, 50, 60, 70, 80, 90, None],
        rows
    ),

    "Study_Hours_Per_Day": np.random.choice(
        [1, 2, 3, 4, 5, None],
        rows
    ),

    "Parent_Contact": np.random.choice(
        ["Yes", "No", "YES", "NO", None],
        rows
    ),

    "School_Fee_Paid": np.random.choice(
        ["Paid", "Unpaid", "paid", "unpaid", None],
        rows
    ),

    "Distance_from_School_km": np.random.choice(
        [0.5, 1, 2, 3, 5, 8, None],
        rows
    )
})

# Export to CSV
file_path = "D:\\EduNet\\NSTI_Indore25_26\\Data Generation\\fake_school_data_powerbi.csv"
df.to_csv(file_path, index=False)

print("CSV file generated:", file_path)
# Out:
# CSV file generated: D:\EduNet\NSTI_Indore25_26\Data Generation\fake_school_data_powerbi.csv
